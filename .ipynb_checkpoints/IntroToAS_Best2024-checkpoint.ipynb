# %% [markdown]
# <h3 align = "center"> Introduction to Differential Splicing Analysis with Python </h3>
# <hr>
# <h4 align = "center"> Bioinformatics with Python & Pandas </h4>
#
# <h3 align = "center"> <img src="https://files.realpython.com/media/Python-Pandas-10-Tricks--Features-You-May-Not-Know-Watermark.e58bb5ce9835.jpg" width="500"/>
#
# <h4 align = "center"> Paulo Caldas | FCT-NOVA | cOMICS Lab </h4>
# <hr>

# %% [markdown]
# ### Why Pandas?
# - Pandas is one of the most powerful libraries for anything related with data science <br>
# - Provides fast, flexible, easy and intuitive data manipulation of data frames <br>
# - Allows to work with big data sets and/or multiple files at once <br>
#
# ### About Pandas
# - `pandas` runs on top of `numpy`
# - Provides high-level data structure (Data Frames) --> they look like spreadsheets!
# - Contains built-in functions to clean, group, merge, and concatenate tabular data
# - Easy to apply `numpy` and `scipy` functions on tabular data
#
# ### Install Pandas
# ... if you installed Anaconda you're good to go!
# - Anaconda is a popular distribution of the Python (and R programming languages actually!) for scientific computing and data science.
# - It comes with a wide range of pre-installed packages commonly used in these fields - making it convenient for users to get startedision tasks.

# %% [markdown]
# ### <span style='color:darkblue'> Step 0 - Import Packages

# %%
# packages for data manipulation and math operations
# explain rationale behind packages and functions if needed
import pandas as pd
import numpy as np

# packages for data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### <span style='color:darkblue'> Step 1 - Import Data (Output from VastTools)
# - more on vast-tools: https://github.com/vastgroup/vast-tools
# - data: PSI values from mammalian organ development: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6658352/
#
# ![image.png](attachment:4d0711dc-32d9-4db0-8b0c-6a854260a0d3.png)

# %%
# import data - Understand the data
inclusion_table = pd.read_table('data/betaAS_inclusion_table_reshaped.txt')
inclusion_table
# Out:
#          GENE         EVENT                     COORD  LENGTH COMPLEX  \
# 0       LAS1L  HsaEX0035417    chrX:64734703-64734850     148       S
# 1       KRIT1  HsaEX0035028    chr7:91843925-91844091     167       S
# 2        LAP3  HsaEX0035326    chr4:17598669-17598757      89       S
# 3        CD99  HsaEX0013932      chrX:2635646-2635693      48       S
# 4     SPATA20  HsaEX0061239   chr17:48625915-48625979      65       S
# ...       ...           ...                       ...     ...     ...
# 1681     GNAS  HsaEX0027840   chr20:57474530-57474532       3      C1
# 1682    AP2M1  HsaEX0004932  chr3:183898433-183898438       6      C1
# 1683     PSAP  HsaEX0050522   chr10:73583645-73583653       9      C1
# 1684     PHB2  HsaEX0046902     chr12:7075074-7075079       6      C1
# 1685  POLR2J2  HsaEX0049073  chr7:102311787-102311789       3      C1
#
#       FOREBRAIN.ADOLESCENT_ERR2598266  FOREBRAIN.ADOLESCENT_ERR2598267  \
# 0                              100.00                           100.00
# 1                              100.00                           100.00
# 2                               94.24                            95.34
# 3                               74.32                           100.00
# 4                              100.00                           100.00
# ...                               ...                              ...
# 1681                            16.22                            15.28
# 1682                            96.61                            97.26
# 1683                            94.02                            96.51
# 1684                           100.00                           100.00
# 1685                            72.92                            64.49
#
#       FOREBRAIN.ADOLESCENT_ERR2598268  FOREBRAIN.ADOLESCENT_ERR2598269  \
# 0                              100.00                           100.00
# 1                              100.00                           100.00
# 2                               97.94                           100.00
# 3                               97.67                           100.00
# 4                              100.00                           100.00
# ...                               ...                              ...
# 1681                            13.34                            14.22
# 1682                            92.34                            95.96
# 1683                            58.55                            93.72
# 1684                           100.00                           100.00
# 1685                            78.51                            67.79
#
#       FOREBRAIN.ELDERLY_ERR2598280  ...  HEART.ADOLESCENT_ERR2598270  \
# 0                           100.00  ...                       100.00
# 1                           100.00  ...                       100.00
# 2                           100.00  ...                       100.00
# 3                            96.29  ...                        92.50
# 4                           100.00  ...                       100.00
# ...                            ...  ...                          ...
# 1681                         10.33  ...                        10.49
# 1682                         91.31  ...                        83.24
# 1683                         91.46  ...                        12.05
# 1684                        100.00  ...                       100.00
# 1685                         82.17  ...                        70.47
#
#       HEART.MIDDLE_ADULT_ERR2598307  HEART.YOUNG_ADULT_ERR2598351  \
# 0                            100.00                        100.00
# 1                            100.00                        100.00
# 2                             98.21                        100.00
# 3                             94.71                         94.65
# 4                            100.00                        100.00
# ...                             ...                           ...
# 1681                          14.59                         13.64
# 1682                          96.81                         97.52
# 1683                          96.49                         90.69
# 1684                         100.00                        100.00
# 1685                          44.22                         58.04
#
#       LIVER.ADOLESCENT_ERR2598275  LIVER.ELDERLY_ERR2598284  \
# 0                          100.00                    100.00
# 1                          100.00                    100.00
# 2                           97.43                    100.00
# 3                           90.74                     92.49
# 4                          100.00                    100.00
# ...                           ...                       ...
# 1681                        13.74                     13.95
# 1682                        95.97                     96.92
# 1683                        98.00                     98.07
# 1684                       100.00                    100.00
# 1685                        85.06                     69.87
#
#       LIVER.ELDERLY_ERR2598285  LIVER.MIDDLE_ADULT_ERR2598310  \
# 0                       100.00                         100.00
# 1                       100.00                         100.00
# 2                        98.49                          98.25
# 3                        96.69                          88.61
# 4                       100.00                         100.00
# ...                        ...                            ...
# 1681                     16.68                          12.89
# 1682                     95.14                          90.02
# 1683                     92.63                          90.02
# 1684                    100.00                         100.00
# 1685                     43.15                          80.13
#
#       LIVER.YOUNG_ADULT_ERR2598357  LIVER.YOUNG_ADULT_ERR2598358  \
# 0                           100.00                        100.00
# 1                           100.00                        100.00
# 2                           100.00                         99.14
# 3                            98.55                         95.41
# 4                           100.00                        100.00
# ...                            ...                           ...
# 1681                          9.87                         19.71
# 1682                         79.43                         79.47
# 1683                         13.43                          9.57
# 1684                        100.00                        100.00
# 1685                         61.75                         85.13
#
#       LIVER.YOUNG_ADULT_ERR2598359
# 0                           100.00
# 1                           100.00
# 2                            98.50
# 3                           100.00
# 4                           100.00
# ...                            ...
# 1681                          4.54
# 1682                         81.76
# 1683                         12.94
# 1684                        100.00
# 1685                         87.04
#
# [1686 rows x 28 columns]

# %% [markdown]
# ### <span style='color:darkblue'> Step 2 - General Exploratory Analysis

# %%
inclusion_table.columns
#inclusion_table.shape
#inclusion_table.info() #check overall info of each column
#inclusion_table.describe() # overall statistics for numeric columns
#inclusion_table.head() # check the top of the table
#inclusion_table.tail() # check bottom of the table
#inclusion_table.columns # check all headers
#inclusion_table['GENE'] # select column
#inclusion_table[['GENE','EVENT','COMPLEX']] # get a subtable selecting mutiple columns (slice by columns)
#inclusion_table.iloc[60] # check row number 60 on the list
#inclusion_table.iloc[300:400] #check slice of rows
#inclusion_table['LENGHT'].mean() # check mean of one column
#inclusion_table['LENGHT'].std() # chech standard deviation of one column
#inclusion_table['GENE'].unique() # how many different values exist along the column

# ... and much more # ...
# Out:
# Index(['GENE', 'EVENT', 'COORD', 'LENGTH', 'COMPLEX',
#        'FOREBRAIN.ADOLESCENT_ERR2598266', 'FOREBRAIN.ADOLESCENT_ERR2598267',
#        'FOREBRAIN.ADOLESCENT_ERR2598268', 'FOREBRAIN.ADOLESCENT_ERR2598269',
#        'FOREBRAIN.ELDERLY_ERR2598280', 'FOREBRAIN.ELDERLY_ERR2598281',
#        'FOREBRAIN.MIDDLE_ADULT_ERR2598305',
#        'FOREBRAIN.MIDDLE_ADULT_ERR2598306', 'FOREBRAIN.YOUNG_ADULT_ERR2598346',
#        'FOREBRAIN.YOUNG_ADULT_ERR2598347', 'FOREBRAIN.YOUNG_ADULT_ERR2598348',
#        'FOREBRAIN.YOUNG_ADULT_ERR2598349', 'FOREBRAIN.YOUNG_ADULT_ERR2598350',
#        'HEART.ADOLESCENT_ERR2598270', 'HEART.MIDDLE_ADULT_ERR2598307',
#        'HEART.YOUNG_ADULT_ERR2598351', 'LIVER.ADOLESCENT_ERR2598275',
#        'LIVER.ELDERLY_ERR2598284', 'LIVER.ELDERLY_ERR2598285',
#        'LIVER.MIDDLE_ADULT_ERR2598310', 'LIVER.YOUNG_ADULT_ERR2598357',
#        'LIVER.YOUNG_ADULT_ERR2598358', 'LIVER.YOUNG_ADULT_ERR2598359'],
#       dtype='object')

# %% [markdown]
# #### Which genes have the greatest variety of isoforms?
# - learn basic plotting from data frame

# %%
# quicly access distribution of the data -> but not the best way for plotting
#inclusion_table['GENE'].value_counts().plot(kind = 'density');
inclusion_table['GENE'].value_counts().head(20).plot(kind = 'bar', color = 'crimson', figsize = (10,4), edgecolor = 'k');

# %%
inclusion_table['FOREBRAIN.ADOLESCENT_ERR2598268'].plot(kind = 'density');
inclusion_table['FOREBRAIN.ELDERLY_ERR2598280'].plot(kind = 'density');

# %% [markdown]
# #### What is the relative % of alternative splicing events?
#
# **Column 6: Type of event**
# - S, C1, C2, C3: exon skipping (EX) events with increasing degrees of complexity
# - IR: intron retention event
# - Alt3: ALTA events
# - Alt5: ALTD events

# %%
event_counts = inclusion_table['COMPLEX'].value_counts()
plt.pie(event_counts, labels = event_counts.index);

# %% [markdown]
# ### Viasualize PSI across samples with a heatmap

# %%
heatmap_data = inclusion_table.set_index('EVENT').drop(['GENE','COORD','LENGTH','COMPLEX'], axis = 1)
mean_psi_index = heatmap_data.mean(axis=1).sort_values().index
heatmap_data = heatmap_data.loc[mean_psi_index].head(100)

# show plot
sns.heatmap(heatmap_data);

# %%
heatmap_data = inclusion_table.set_index('EVENT').drop(['GENE','COORD','LENGTH','COMPLEX'], axis = 1)

# organize by mean PSI value
mean_psi_index = heatmap_data.mean(axis = 1).sort_values(ascending = True).index
heatmap_data = heatmap_data.loc[mean_psi_index]
heatmap_data
# Out:
#               FOREBRAIN.ADOLESCENT_ERR2598266  \
# EVENT
# HsaEX0018545                             5.66
# HsaEX0060708                             6.54
# HsaEX0042343                             4.68
# HsaEX0048569                             3.87
# HsaEX0057743                             1.23
# ...                                       ...
# HsaEX0006809                           100.00
# HsaEX0069539                           100.00
# HsaEX0018963                           100.00
# HsaEX0004961                           100.00
# HsaEX0035417                           100.00
#
#               FOREBRAIN.ADOLESCENT_ERR2598267  \
# EVENT
# HsaEX0018545                             2.22
# HsaEX0060708                             3.28
# HsaEX0042343                             5.40
# HsaEX0048569                             3.93
# HsaEX0057743                             6.67
# ...                                       ...
# HsaEX0006809                           100.00
# HsaEX0069539                           100.00
# HsaEX0018963                           100.00
# HsaEX0004961                           100.00
# HsaEX0035417                           100.00
#
#               FOREBRAIN.ADOLESCENT_ERR2598268  \
# EVENT
# HsaEX0018545                             2.79
# HsaEX0060708                             7.02
# HsaEX0042343                             2.82
# HsaEX0048569                             2.79
# HsaEX0057743                             6.33
# ...                                       ...
# HsaEX0006809                           100.00
# HsaEX0069539                           100.00
# HsaEX0018963                           100.00
# HsaEX0004961                           100.00
# HsaEX0035417                           100.00
#
#               FOREBRAIN.ADOLESCENT_ERR2598269  FOREBRAIN.ELDERLY_ERR2598280  \
# EVENT
# HsaEX0018545                             2.70                          8.64
# HsaEX0060708                             4.77                          1.31
# HsaEX0042343                             2.70                          1.41
# HsaEX0048569                             5.77                          3.65
# HsaEX0057743                             6.90                          1.96
# ...                                       ...                           ...
# HsaEX0006809                           100.00                        100.00
# HsaEX0069539                           100.00                        100.00
# HsaEX0018963                           100.00                        100.00
# HsaEX0004961                           100.00                        100.00
# HsaEX0035417                           100.00                        100.00
#
#               FOREBRAIN.ELDERLY_ERR2598281  FOREBRAIN.MIDDLE_ADULT_ERR2598305  \
# EVENT
# HsaEX0018545                          6.12                               1.20
# HsaEX0060708                          3.99                               7.89
# HsaEX0042343                          5.05                               1.40
# HsaEX0048569                         13.01                               2.64
# HsaEX0057743                          7.55                               6.52
# ...                                    ...                                ...
# HsaEX0006809                        100.00                             100.00
# HsaEX0069539                        100.00                             100.00
# HsaEX0018963                        100.00                             100.00
# HsaEX0004961                        100.00                             100.00
# HsaEX0035417                        100.00                             100.00
#
#               FOREBRAIN.MIDDLE_ADULT_ERR2598306  \
# EVENT
# HsaEX0018545                               5.43
# HsaEX0060708                               5.34
# HsaEX0042343                               4.11
# HsaEX0048569                               6.09
# HsaEX0057743                               5.17
# ...                                         ...
# HsaEX0006809                             100.00
# HsaEX0069539                             100.00
# HsaEX0018963                             100.00
# HsaEX0004961                             100.00
# HsaEX0035417                             100.00
#
#               FOREBRAIN.YOUNG_ADULT_ERR2598346  \
# EVENT
# HsaEX0018545                              5.75
# HsaEX0060708                              2.70
# HsaEX0042343                              8.24
# HsaEX0048569                             11.84
# HsaEX0057743                              8.98
# ...                                        ...
# HsaEX0006809                            100.00
# HsaEX0069539                            100.00
# HsaEX0018963                            100.00
# HsaEX0004961                            100.00
# HsaEX0035417                            100.00
#
#               FOREBRAIN.YOUNG_ADULT_ERR2598347  ...  \
# EVENT                                           ...
# HsaEX0018545                              5.45  ...
# HsaEX0060708                              8.13  ...
# HsaEX0042343                             27.98  ...
# HsaEX0048569                              9.97  ...
# HsaEX0057743                             12.82  ...
# ...                                        ...  ...
# HsaEX0006809                            100.00  ...
# HsaEX0069539                            100.00  ...
# HsaEX0018963                            100.00  ...
# HsaEX0004961                            100.00  ...
# HsaEX0035417                            100.00  ...
#
#               HEART.ADOLESCENT_ERR2598270  HEART.MIDDLE_ADULT_ERR2598307  \
# EVENT
# HsaEX0018545                         2.07                           4.31
# HsaEX0060708                         2.38                           4.06
# HsaEX0042343                         8.67                           5.56
# HsaEX0048569                        10.07                           2.70
# HsaEX0057743                         6.25                           1.08
# ...                                   ...                            ...
# HsaEX0006809                       100.00                         100.00
# HsaEX0069539                       100.00                         100.00
# HsaEX0018963                       100.00                         100.00
# HsaEX0004961                       100.00                         100.00
# HsaEX0035417                       100.00                         100.00
#
#               HEART.YOUNG_ADULT_ERR2598351  LIVER.ADOLESCENT_ERR2598275  \
# EVENT
# HsaEX0018545                          2.22                         1.67
# HsaEX0060708                          2.79                         2.90
# HsaEX0042343                          4.94                         4.58
# HsaEX0048569                          2.33                         4.05
# HsaEX0057743                          4.62                        10.53
# ...                                    ...                          ...
# HsaEX0006809                        100.00                       100.00
# HsaEX0069539                        100.00                       100.00
# HsaEX0018963                        100.00                       100.00
# HsaEX0004961                        100.00                       100.00
# HsaEX0035417                        100.00                       100.00
#
#               LIVER.ELDERLY_ERR2598284  LIVER.ELDERLY_ERR2598285  \
# EVENT
# HsaEX0018545                      5.56                      1.33
# HsaEX0060708                      3.31                      4.05
# HsaEX0042343                      2.54                      4.20
# HsaEX0048569                      7.24                      2.93
# HsaEX0057743                      1.59                      3.80
# ...                                ...                       ...
# HsaEX0006809                    100.00                    100.00
# HsaEX0069539                    100.00                    100.00
# HsaEX0018963                    100.00                    100.00
# HsaEX0004961                    100.00                    100.00
# HsaEX0035417                    100.00                    100.00
#
#               LIVER.MIDDLE_ADULT_ERR2598310  LIVER.YOUNG_ADULT_ERR2598357  \
# EVENT
# HsaEX0018545                           2.74                          8.40
# HsaEX0060708                           1.75                          5.49
# HsaEX0042343                           1.20                         12.32
# HsaEX0048569                           5.48                         11.49
# HsaEX0057743                           6.42                          4.35
# ...                                     ...                           ...
# HsaEX0006809                         100.00                        100.00
# HsaEX0069539                         100.00                        100.00
# HsaEX0018963                         100.00                        100.00
# HsaEX0004961                         100.00                        100.00
# HsaEX0035417                         100.00                        100.00
#
#               LIVER.YOUNG_ADULT_ERR2598358  LIVER.YOUNG_ADULT_ERR2598359
# EVENT
# HsaEX0018545                          4.70                          5.19
# HsaEX0060708                          1.55                          4.97
# HsaEX0042343                          9.28                          7.53
# HsaEX0048569                          7.95                         11.66
# HsaEX0057743                          4.35                         11.94
# ...                                    ...                           ...
# HsaEX0006809                        100.00                        100.00
# HsaEX0069539                        100.00                        100.00
# HsaEX0018963                        100.00                        100.00
# HsaEX0004961                        100.00                        100.00
# HsaEX0035417                        100.00                        100.00
#
# [1686 rows x 23 columns]

# %%
plt.figure(figsize = (6,6), dpi = 120)
sns.heatmap(heatmap_data);

# %% [markdown]
# #### What are the most relevant events?
# - the ones that vary the most across samples?

# %%
inclusion_table_var = inclusion_table.set_index(['GENE', 'EVENT']).drop(['COORD','LENGTH','COMPLEX'], axis = 1)
inclusion_table_var['VAR'] = inclusion_table_var.std(axis = 1)
inclusion_table_var.sort_values('VAR', ascending = False)
# Out:
#                       FOREBRAIN.ADOLESCENT_ERR2598266  \
# GENE    EVENT
# EPN1    HsaEX0022820                            11.33
# SUGP2   HsaEX0062842                            19.54
# APLP2   HsaEX0005151                            88.68
# PSAP    HsaEX0050522                            94.02
# INTS10  HsaEX0031861                            84.27
# ...                                               ...
# CCDC130 HsaEX0012976                           100.00
# INTS10  HsaEX0031852                           100.00
# RBL2    HsaEX0052597                           100.00
# CLCN7   HsaEX0015565                           100.00
# TXNDC11 HsaEX0068440                           100.00
#
#                       FOREBRAIN.ADOLESCENT_ERR2598267  \
# GENE    EVENT
# EPN1    HsaEX0022820                            11.33
# SUGP2   HsaEX0062842                            18.02
# APLP2   HsaEX0005151                            94.33
# PSAP    HsaEX0050522                            96.51
# INTS10  HsaEX0031861                            75.44
# ...                                               ...
# CCDC130 HsaEX0012976                           100.00
# INTS10  HsaEX0031852                           100.00
# RBL2    HsaEX0052597                           100.00
# CLCN7   HsaEX0015565                           100.00
# TXNDC11 HsaEX0068440                           100.00
#
#                       FOREBRAIN.ADOLESCENT_ERR2598268  \
# GENE    EVENT
# EPN1    HsaEX0022820                            35.89
# SUGP2   HsaEX0062842                            11.93
# APLP2   HsaEX0005151                            69.53
# PSAP    HsaEX0050522                            58.55
# INTS10  HsaEX0031861                            50.91
# ...                                               ...
# CCDC130 HsaEX0012976                           100.00
# INTS10  HsaEX0031852                           100.00
# RBL2    HsaEX0052597                           100.00
# CLCN7   HsaEX0015565                           100.00
# TXNDC11 HsaEX0068440                           100.00
#
#                       FOREBRAIN.ADOLESCENT_ERR2598269  \
# GENE    EVENT
# EPN1    HsaEX0022820                            12.66
# SUGP2   HsaEX0062842                             7.85
# APLP2   HsaEX0005151                            87.48
# PSAP    HsaEX0050522                            93.72
# INTS10  HsaEX0031861                            77.14
# ...                                               ...
# CCDC130 HsaEX0012976                           100.00
# INTS10  HsaEX0031852                           100.00
# RBL2    HsaEX0052597                           100.00
# CLCN7   HsaEX0015565                           100.00
# TXNDC11 HsaEX0068440                           100.00
#
#                       FOREBRAIN.ELDERLY_ERR2598280  \
# GENE    EVENT
# EPN1    HsaEX0022820                         87.17
# SUGP2   HsaEX0062842                         22.22
# APLP2   HsaEX0005151                         11.50
# PSAP    HsaEX0050522                         91.46
# INTS10  HsaEX0031861                         18.92
# ...                                            ...
# CCDC130 HsaEX0012976                        100.00
# INTS10  HsaEX0031852                        100.00
# RBL2    HsaEX0052597                        100.00
# CLCN7   HsaEX0015565                        100.00
# TXNDC11 HsaEX0068440                        100.00
#
#                       FOREBRAIN.ELDERLY_ERR2598281  \
# GENE    EVENT
# EPN1    HsaEX0022820                        100.00
# SUGP2   HsaEX0062842                        100.00
# APLP2   HsaEX0005151                         22.48
# PSAP    HsaEX0050522                         17.71
# INTS10  HsaEX0031861                          2.99
# ...                                            ...
# CCDC130 HsaEX0012976                        100.00
# INTS10  HsaEX0031852                        100.00
# RBL2    HsaEX0052597                        100.00
# CLCN7   HsaEX0015565                        100.00
# TXNDC11 HsaEX0068440                        100.00
#
#                       FOREBRAIN.MIDDLE_ADULT_ERR2598305  \
# GENE    EVENT
# EPN1    HsaEX0022820                              14.76
# SUGP2   HsaEX0062842                               7.10
# APLP2   HsaEX0005151                              80.27
# PSAP    HsaEX0050522                              90.79
# INTS10  HsaEX0031861                              62.58
# ...                                                 ...
# CCDC130 HsaEX0012976                             100.00
# INTS10  HsaEX0031852                             100.00
# RBL2    HsaEX0052597                             100.00
# CLCN7   HsaEX0015565                             100.00
# TXNDC11 HsaEX0068440                             100.00
#
#                       FOREBRAIN.MIDDLE_ADULT_ERR2598306  \
# GENE    EVENT
# EPN1    HsaEX0022820                              13.93
# SUGP2   HsaEX0062842                              12.98
# APLP2   HsaEX0005151                              88.68
# PSAP    HsaEX0050522                              96.77
# INTS10  HsaEX0031861                              82.06
# ...                                                 ...
# CCDC130 HsaEX0012976                             100.00
# INTS10  HsaEX0031852                             100.00
# RBL2    HsaEX0052597                             100.00
# CLCN7   HsaEX0015565                             100.00
# TXNDC11 HsaEX0068440                             100.00
#
#                       FOREBRAIN.YOUNG_ADULT_ERR2598346  \
# GENE    EVENT
# EPN1    HsaEX0022820                            100.00
# SUGP2   HsaEX0062842                             94.81
# APLP2   HsaEX0005151                             15.47
# PSAP    HsaEX0050522                             26.49
# INTS10  HsaEX0031861                              1.73
# ...                                                ...
# CCDC130 HsaEX0012976                            100.00
# INTS10  HsaEX0031852                            100.00
# RBL2    HsaEX0052597                            100.00
# CLCN7   HsaEX0015565                            100.00
# TXNDC11 HsaEX0068440                            100.00
#
#                       FOREBRAIN.YOUNG_ADULT_ERR2598347  ...  \
# GENE    EVENT                                           ...
# EPN1    HsaEX0022820                             78.45  ...
# SUGP2   HsaEX0062842                             79.49  ...
# APLP2   HsaEX0005151                             33.42  ...
# PSAP    HsaEX0050522                             74.75  ...
# INTS10  HsaEX0031861                              8.20  ...
# ...                                                ...  ...
# CCDC130 HsaEX0012976                            100.00  ...
# INTS10  HsaEX0031852                            100.00  ...
# RBL2    HsaEX0052597                            100.00  ...
# CLCN7   HsaEX0015565                            100.00  ...
# TXNDC11 HsaEX0068440                            100.00  ...
#
#                       HEART.MIDDLE_ADULT_ERR2598307  \
# GENE    EVENT
# EPN1    HsaEX0022820                          14.04
# SUGP2   HsaEX0062842                          14.89
# APLP2   HsaEX0005151                          85.65
# PSAP    HsaEX0050522                          96.49
# INTS10  HsaEX0031861                          69.16
# ...                                             ...
# CCDC130 HsaEX0012976                         100.00
# INTS10  HsaEX0031852                         100.00
# RBL2    HsaEX0052597                         100.00
# CLCN7   HsaEX0015565                         100.00
# TXNDC11 HsaEX0068440                         100.00
#
#                       HEART.YOUNG_ADULT_ERR2598351  \
# GENE    EVENT
# EPN1    HsaEX0022820                         24.03
# SUGP2   HsaEX0062842                         12.50
# APLP2   HsaEX0005151                         86.84
# PSAP    HsaEX0050522                         90.69
# INTS10  HsaEX0031861                         75.84
# ...                                            ...
# CCDC130 HsaEX0012976                        100.00
# INTS10  HsaEX0031852                        100.00
# RBL2    HsaEX0052597                        100.00
# CLCN7   HsaEX0015565                        100.00
# TXNDC11 HsaEX0068440                        100.00
#
#                       LIVER.ADOLESCENT_ERR2598275  LIVER.ELDERLY_ERR2598284  \
# GENE    EVENT
# EPN1    HsaEX0022820                         6.56                     16.92
# SUGP2   HsaEX0062842                        12.30                     10.05
# APLP2   HsaEX0005151                        82.43                     91.82
# PSAP    HsaEX0050522                        98.00                     98.07
# INTS10  HsaEX0031861                        68.66                     74.36
# ...                                           ...                       ...
# CCDC130 HsaEX0012976                       100.00                    100.00
# INTS10  HsaEX0031852                       100.00                    100.00
# RBL2    HsaEX0052597                       100.00                    100.00
# CLCN7   HsaEX0015565                       100.00                    100.00
# TXNDC11 HsaEX0068440                       100.00                    100.00
#
#                       LIVER.ELDERLY_ERR2598285  LIVER.MIDDLE_ADULT_ERR2598310  \
# GENE    EVENT
# EPN1    HsaEX0022820                     23.89                          69.51
# SUGP2   HsaEX0062842                     28.57                          24.53
# APLP2   HsaEX0005151                     72.79                          12.52
# PSAP    HsaEX0050522                     92.63                          90.02
# INTS10  HsaEX0031861                     67.35                           5.26
# ...                                        ...                            ...
# CCDC130 HsaEX0012976                    100.00                         100.00
# INTS10  HsaEX0031852                    100.00                         100.00
# RBL2    HsaEX0052597                    100.00                         100.00
# CLCN7   HsaEX0015565                    100.00                         100.00
# TXNDC11 HsaEX0068440                    100.00                         100.00
#
#                       LIVER.YOUNG_ADULT_ERR2598357  \
# GENE    EVENT
# EPN1    HsaEX0022820                         97.14
# SUGP2   HsaEX0062842                        100.00
# APLP2   HsaEX0005151                         16.32
# PSAP    HsaEX0050522                         13.43
# INTS10  HsaEX0031861                          2.70
# ...                                            ...
# CCDC130 HsaEX0012976                        100.00
# INTS10  HsaEX0031852                        100.00
# RBL2    HsaEX0052597                        100.00
# CLCN7   HsaEX0015565                        100.00
# TXNDC11 HsaEX0068440                        100.00
#
#                       LIVER.YOUNG_ADULT_ERR2598358  \
# GENE    EVENT
# EPN1    HsaEX0022820                        100.00
# SUGP2   HsaEX0062842                        100.00
# APLP2   HsaEX0005151                          5.48
# PSAP    HsaEX0050522                          9.57
# INTS10  HsaEX0031861                          2.67
# ...                                            ...
# CCDC130 HsaEX0012976                        100.00
# INTS10  HsaEX0031852                        100.00
# RBL2    HsaEX0052597                        100.00
# CLCN7   HsaEX0015565                        100.00
# TXNDC11 HsaEX0068440                        100.00
#
#                       LIVER.YOUNG_ADULT_ERR2598359        VAR
# GENE    EVENT
# EPN1    HsaEX0022820                        100.00  39.133349
# SUGP2   HsaEX0062842                         90.32  37.164678
# APLP2   HsaEX0005151                         11.86  35.170628
# PSAP    HsaEX0050522                         12.94  34.816377
# INTS10  HsaEX0031861                          4.50  34.120752
# ...                                            ...        ...
# CCDC130 HsaEX0012976                        100.00   0.000000
# INTS10  HsaEX0031852                        100.00   0.000000
# RBL2    HsaEX0052597                        100.00   0.000000
# CLCN7   HsaEX0015565                        100.00   0.000000
# TXNDC11 HsaEX0068440                        100.00   0.000000
#
# [1686 rows x 24 columns]

# %%
inclusion_table_var = inclusion_table.set_index(['GENE', 'EVENT']).drop(['COORD','LENGTH','COMPLEX'], axis = 1)
inclusion_table_var['PSI_VAR'] = inclusion_table_var.std(axis = 1)

# discard lines where variance is close to zero
inclusion_table_var = inclusion_table_var[inclusion_table_var['PSI_VAR'] > 1]

# sort rows by variance
inclusion_table_var = inclusion_table_var.sort_values('PSI_VAR', ascending=False)
inclusion_table_var
# Out:
#                      FOREBRAIN.ADOLESCENT_ERR2598266  \
# GENE   EVENT
# EPN1   HsaEX0022820                            11.33
# SUGP2  HsaEX0062842                            19.54
# APLP2  HsaEX0005151                            88.68
# PSAP   HsaEX0050522                            94.02
# INTS10 HsaEX0031861                            84.27
# ...                                              ...
# DDA1   HsaEX0018806                            97.69
# HAGH   HsaEX0029225                            98.07
# GBF1   HsaEX0027148                           100.00
# ECSIT  HsaEX0021526                           100.00
# CTBP1  HsaEX0017668                           100.00
#
#                      FOREBRAIN.ADOLESCENT_ERR2598267  \
# GENE   EVENT
# EPN1   HsaEX0022820                            11.33
# SUGP2  HsaEX0062842                            18.02
# APLP2  HsaEX0005151                            94.33
# PSAP   HsaEX0050522                            96.51
# INTS10 HsaEX0031861                            75.44
# ...                                              ...
# DDA1   HsaEX0018806                            99.71
# HAGH   HsaEX0029225                            98.69
# GBF1   HsaEX0027148                           100.00
# ECSIT  HsaEX0021526                            97.74
# CTBP1  HsaEX0017668                           100.00
#
#                      FOREBRAIN.ADOLESCENT_ERR2598268  \
# GENE   EVENT
# EPN1   HsaEX0022820                            35.89
# SUGP2  HsaEX0062842                            11.93
# APLP2  HsaEX0005151                            69.53
# PSAP   HsaEX0050522                            58.55
# INTS10 HsaEX0031861                            50.91
# ...                                              ...
# DDA1   HsaEX0018806                            98.86
# HAGH   HsaEX0029225                            98.35
# GBF1   HsaEX0027148                           100.00
# ECSIT  HsaEX0021526                            98.77
# CTBP1  HsaEX0017668                           100.00
#
#                      FOREBRAIN.ADOLESCENT_ERR2598269  \
# GENE   EVENT
# EPN1   HsaEX0022820                            12.66
# SUGP2  HsaEX0062842                             7.85
# APLP2  HsaEX0005151                            87.48
# PSAP   HsaEX0050522                            93.72
# INTS10 HsaEX0031861                            77.14
# ...                                              ...
# DDA1   HsaEX0018806                            99.26
# HAGH   HsaEX0029225                            94.55
# GBF1   HsaEX0027148                           100.00
# ECSIT  HsaEX0021526                           100.00
# CTBP1  HsaEX0017668                           100.00
#
#                      FOREBRAIN.ELDERLY_ERR2598280  \
# GENE   EVENT
# EPN1   HsaEX0022820                         87.17
# SUGP2  HsaEX0062842                         22.22
# APLP2  HsaEX0005151                         11.50
# PSAP   HsaEX0050522                         91.46
# INTS10 HsaEX0031861                         18.92
# ...                                           ...
# DDA1   HsaEX0018806                        100.00
# HAGH   HsaEX0029225                         96.42
# GBF1   HsaEX0027148                        100.00
# ECSIT  HsaEX0021526                        100.00
# CTBP1  HsaEX0017668                        100.00
#
#                      FOREBRAIN.ELDERLY_ERR2598281  \
# GENE   EVENT
# EPN1   HsaEX0022820                        100.00
# SUGP2  HsaEX0062842                        100.00
# APLP2  HsaEX0005151                         22.48
# PSAP   HsaEX0050522                         17.71
# INTS10 HsaEX0031861                          2.99
# ...                                           ...
# DDA1   HsaEX0018806                        100.00
# HAGH   HsaEX0029225                         98.28
# GBF1   HsaEX0027148                        100.00
# ECSIT  HsaEX0021526                        100.00
# CTBP1  HsaEX0017668                        100.00
#
#                      FOREBRAIN.MIDDLE_ADULT_ERR2598305  \
# GENE   EVENT
# EPN1   HsaEX0022820                              14.76
# SUGP2  HsaEX0062842                               7.10
# APLP2  HsaEX0005151                              80.27
# PSAP   HsaEX0050522                              90.79
# INTS10 HsaEX0031861                              62.58
# ...                                                ...
# DDA1   HsaEX0018806                             100.00
# HAGH   HsaEX0029225                              98.92
# GBF1   HsaEX0027148                             100.00
# ECSIT  HsaEX0021526                              98.22
# CTBP1  HsaEX0017668                             100.00
#
#                      FOREBRAIN.MIDDLE_ADULT_ERR2598306  \
# GENE   EVENT
# EPN1   HsaEX0022820                              13.93
# SUGP2  HsaEX0062842                              12.98
# APLP2  HsaEX0005151                              88.68
# PSAP   HsaEX0050522                              96.77
# INTS10 HsaEX0031861                              82.06
# ...                                                ...
# DDA1   HsaEX0018806                              99.15
# HAGH   HsaEX0029225                              98.68
# GBF1   HsaEX0027148                             100.00
# ECSIT  HsaEX0021526                              99.37
# CTBP1  HsaEX0017668                             100.00
#
#                      FOREBRAIN.YOUNG_ADULT_ERR2598346  \
# GENE   EVENT
# EPN1   HsaEX0022820                            100.00
# SUGP2  HsaEX0062842                             94.81
# APLP2  HsaEX0005151                             15.47
# PSAP   HsaEX0050522                             26.49
# INTS10 HsaEX0031861                              1.73
# ...                                               ...
# DDA1   HsaEX0018806                            100.00
# HAGH   HsaEX0029225                             97.65
# GBF1   HsaEX0027148                            100.00
# ECSIT  HsaEX0021526                            100.00
# CTBP1  HsaEX0017668                            100.00
#
#                      FOREBRAIN.YOUNG_ADULT_ERR2598347  ...  \
# GENE   EVENT                                           ...
# EPN1   HsaEX0022820                             78.45  ...
# SUGP2  HsaEX0062842                             79.49  ...
# APLP2  HsaEX0005151                             33.42  ...
# PSAP   HsaEX0050522                             74.75  ...
# INTS10 HsaEX0031861                              8.20  ...
# ...                                               ...  ...
# DDA1   HsaEX0018806                            100.00  ...
# HAGH   HsaEX0029225                             98.71  ...
# GBF1   HsaEX0027148                            100.00  ...
# ECSIT  HsaEX0021526                            100.00  ...
# CTBP1  HsaEX0017668                            100.00  ...
#
#                      HEART.MIDDLE_ADULT_ERR2598307  \
# GENE   EVENT
# EPN1   HsaEX0022820                          14.04
# SUGP2  HsaEX0062842                          14.89
# APLP2  HsaEX0005151                          85.65
# PSAP   HsaEX0050522                          96.49
# INTS10 HsaEX0031861                          69.16
# ...                                            ...
# DDA1   HsaEX0018806                          98.87
# HAGH   HsaEX0029225                          98.57
# GBF1   HsaEX0027148                         100.00
# ECSIT  HsaEX0021526                          97.18
# CTBP1  HsaEX0017668                         100.00
#
#                      HEART.YOUNG_ADULT_ERR2598351  \
# GENE   EVENT
# EPN1   HsaEX0022820                         24.03
# SUGP2  HsaEX0062842                         12.50
# APLP2  HsaEX0005151                         86.84
# PSAP   HsaEX0050522                         90.69
# INTS10 HsaEX0031861                         75.84
# ...                                           ...
# DDA1   HsaEX0018806                         99.63
# HAGH   HsaEX0029225                         98.79
# GBF1   HsaEX0027148                         97.48
# ECSIT  HsaEX0021526                         99.09
# CTBP1  HsaEX0017668                        100.00
#
#                      LIVER.ADOLESCENT_ERR2598275  LIVER.ELDERLY_ERR2598284  \
# GENE   EVENT
# EPN1   HsaEX0022820                         6.56                     16.92
# SUGP2  HsaEX0062842                        12.30                     10.05
# APLP2  HsaEX0005151                        82.43                     91.82
# PSAP   HsaEX0050522                        98.00                     98.07
# INTS10 HsaEX0031861                        68.66                     74.36
# ...                                          ...                       ...
# DDA1   HsaEX0018806                        98.96                     99.41
# HAGH   HsaEX0029225                        98.65                     98.67
# GBF1   HsaEX0027148                       100.00                    100.00
# ECSIT  HsaEX0021526                        98.44                    100.00
# CTBP1  HsaEX0017668                       100.00                    100.00
#
#                      LIVER.ELDERLY_ERR2598285  LIVER.MIDDLE_ADULT_ERR2598310  \
# GENE   EVENT
# EPN1   HsaEX0022820                     23.89                          69.51
# SUGP2  HsaEX0062842                     28.57                          24.53
# APLP2  HsaEX0005151                     72.79                          12.52
# PSAP   HsaEX0050522                     92.63                          90.02
# INTS10 HsaEX0031861                     67.35                           5.26
# ...                                       ...                            ...
# DDA1   HsaEX0018806                     98.80                         100.00
# HAGH   HsaEX0029225                     96.91                          97.65
# GBF1   HsaEX0027148                    100.00                         100.00
# ECSIT  HsaEX0021526                    100.00                          99.24
# CTBP1  HsaEX0017668                    100.00                          98.81
#
#                      LIVER.YOUNG_ADULT_ERR2598357  \
# GENE   EVENT
# EPN1   HsaEX0022820                         97.14
# SUGP2  HsaEX0062842                        100.00
# APLP2  HsaEX0005151                         16.32
# PSAP   HsaEX0050522                         13.43
# INTS10 HsaEX0031861                          2.70
# ...                                           ...
# DDA1   HsaEX0018806                        100.00
# HAGH   HsaEX0029225                         98.95
# GBF1   HsaEX0027148                        100.00
# ECSIT  HsaEX0021526                        100.00
# CTBP1  HsaEX0017668                         95.29
#
#                      LIVER.YOUNG_ADULT_ERR2598358  \
# GENE   EVENT
# EPN1   HsaEX0022820                        100.00
# SUGP2  HsaEX0062842                        100.00
# APLP2  HsaEX0005151                          5.48
# PSAP   HsaEX0050522                          9.57
# INTS10 HsaEX0031861                          2.67
# ...                                           ...
# DDA1   HsaEX0018806                         96.48
# HAGH   HsaEX0029225                         98.38
# GBF1   HsaEX0027148                        100.00
# ECSIT  HsaEX0021526                        100.00
# CTBP1  HsaEX0017668                        100.00
#
#                      LIVER.YOUNG_ADULT_ERR2598359    PSI_VAR
# GENE   EVENT
# EPN1   HsaEX0022820                        100.00  39.133349
# SUGP2  HsaEX0062842                         90.32  37.164678
# APLP2  HsaEX0005151                         11.86  35.170628
# PSAP   HsaEX0050522                         12.94  34.816377
# INTS10 HsaEX0031861                          4.50  34.120752
# ...                                           ...        ...
# DDA1   HsaEX0018806                         96.90   1.008093
# HAGH   HsaEX0029225                         97.87   1.005860
# GBF1   HsaEX0027148                        100.00   1.004141
# ECSIT  HsaEX0021526                        100.00   1.003124
# CTBP1  HsaEX0017668                        100.00   1.001969
#
# [1036 rows x 24 columns]

# %% [markdown]
# #### Basic Plotting - Distribution of PSI for a given event

# %%
inclusion_table[inclusion_table['GENE'] == 'EPN1'].filter(like = 'BRAIN')
# Out:
#      FOREBRAIN.ADOLESCENT_ERR2598266  FOREBRAIN.ADOLESCENT_ERR2598267  \
# 412                            11.33                            11.33
# 413                           100.00                           100.00
# 414                           100.00                           100.00
#
#      FOREBRAIN.ADOLESCENT_ERR2598268  FOREBRAIN.ADOLESCENT_ERR2598269  \
# 412                            35.89                            12.66
# 413                           100.00                           100.00
# 414                           100.00                           100.00
#
#      FOREBRAIN.ELDERLY_ERR2598280  FOREBRAIN.ELDERLY_ERR2598281  \
# 412                         87.17                         100.0
# 413                        100.00                         100.0
# 414                        100.00                         100.0
#
#      FOREBRAIN.MIDDLE_ADULT_ERR2598305  FOREBRAIN.MIDDLE_ADULT_ERR2598306  \
# 412                              14.76                              13.93
# 413                             100.00                             100.00
# 414                              99.38                             100.00
#
#      FOREBRAIN.YOUNG_ADULT_ERR2598346  FOREBRAIN.YOUNG_ADULT_ERR2598347  \
# 412                             100.0                             78.45
# 413                             100.0                            100.00
# 414                             100.0                            100.00
#
#      FOREBRAIN.YOUNG_ADULT_ERR2598348  FOREBRAIN.YOUNG_ADULT_ERR2598349  \
# 412                             18.45                             18.32
# 413                            100.00                            100.00
# 414                            100.00                            100.00
#
#      FOREBRAIN.YOUNG_ADULT_ERR2598350
# 412                             90.52
# 413                            100.00
# 414                            100.00

# %%
# show distribution of PSIs for a given event/gene - LIVER VS. BRAIN
event = 'HsaEX0022820'
# HsaEX0047257,HsaEX0047258

event_brain = inclusion_table[inclusion_table['EVENT'] == event].filter(like = 'FOREBRAIN')
event_liver = inclusion_table[inclusion_table['EVENT'] == event].filter(like = 'LIVER')
event_heart = inclusion_table[inclusion_table['EVENT'] == event].filter(like = 'HEART')

# build new data frame for the event
event_df = pd.DataFrame([event_brain.values[0], event_heart.values[0], event_liver.values[0]],
                         index=['brain','heart','liver']).T

# plot
sns.barplot(data = event_df, palette = 'Pastel2');
sns.stripplot(data = event_df, color = 'k');
plt.ylabel('PSI');

# %%
# more plotting
sns.kdeplot(data = event_df, fill = True);
#sns.boxplot(data = event_df);
#sns.violinplot(data = event_df);

# %%
# Show statistical significance ?
from scipy.stats import ttest_ind, mannwhitneyu, wilcoxon

ttest_ind(event_brain.values[0], event_liver.values[0])
# Out:
# TtestResult(statistic=-0.7275355228927098, pvalue=0.4762555024980313, df=18.0)

# %%
# dispine the size of the bars the values are not statistical significant ... even if we try more events ... 
# reason? -> we're tracking variability within tissues and not only between tissues (diff stages?)... more on that later

# %% [markdown]
# ...

# %% [markdown]
# #### EXTRA: For a given gene, plot how the PSI values varie within the gene body? and between Tissues?

# %%
gene = 'EPN1'

brain_gene_exons = inclusion_table[inclusion_table['GENE'] == gene].filter(like = 'BRAIN').mean(axis = 1).reset_index(drop = True)
liver_gene_exons = inclusion_table[inclusion_table['GENE'] == gene].filter(like = 'LIVER').mean(axis = 1).reset_index(drop = True)
heart_gene_exons = inclusion_table[inclusion_table['GENE'] == gene].filter(like = 'HEART').mean(axis = 1).reset_index(drop = True)

#sns.scatter(data = [brain_gene_exons, liver_gene_exons])
#sns.boxplot(data = liver_gene_exons)

gene_exons_tissues = pd.DataFrame([brain_gene_exons, liver_gene_exons, heart_gene_exons], 
                                  index = ['BRAIN','LIVER', 'HEART']).T.reset_index()

# plot varation of exon inclusion along the gene
#plt.figure(figsize = (4,3), dpi = 150)
plt.figure(figsize = (4,3), dpi = 120)
sns.scatterplot(data = gene_exons_tissues, x = 'index', y = 'BRAIN', color = 'steelblue', edgecolor = 'k', s = 30, label = 'Brain')
sns.scatterplot(data = gene_exons_tissues, x = 'index', y = 'LIVER', color = 'seagreen', edgecolor = 'k', s = 30, label = 'Liver')
sns.scatterplot(data = gene_exons_tissues, x = 'index', y = 'HEART', color = 'violet', edgecolor = 'k', s = 30, label = 'Heart')

# make it fancy
plt.title('Levels of Exon Usage along {} \n'.format(gene), fontsize = 10) # add title
plt.ylabel('PSI'); plt.xlabel('Exon Number'); # format axis label
plt.legend(frameon = False, loc = 4); # format legend
sns.despine(trim=True) # make it look like R's plots

# %% [markdown]
# ### <span style='color:darkblue'> Step 3 - Compare Brain vs. Liver
# - Output from ***vast-tools diff***: performs a statistical test to assess whether the PSI distributions of the two compared groups are signficantly different.
# - compares samples taking into account quality of reads and their contribution to the total pool <br>
#
# ![image.png](attachment:acf0d9cb-2998-411e-b3f3-b6442026af81.png)

# %%
# import ouput from vast-tools diff
diff_brain_liver = pd.read_table('data/diff_brain_minus_liver.tab')
diff_brain_liver.sort_values('dPSI')
# Out:
#          GENE         EVENT     BRAIN     LIVER      dPSI  MV[dPsi]
# 412      EPN1  HsaEX0022820  0.135370  0.980334 -0.844964      0.56
# 415     SUGP2  HsaEX0062842  0.210153  0.955099 -0.744945      0.53
# 178      SGCE  HsaEX0057772  0.230930  0.912760 -0.681830      0.44
# 320   RPS6KB2  HsaEX0055638  0.311156  0.989725 -0.678569      0.49
# 688     RPAIN  HsaEX0055409  0.081635  0.744465 -0.662830      0.49
# ...       ...           ...       ...       ...       ...       ...
# 450     MARK3  HsaEX0037926  0.837963  0.215477  0.622485      0.71
# 1145     HM13  HsaEX0030146  0.697954  0.068044  0.629910      0.69
# 469     APLP2  HsaEX0005151  0.885946  0.147085  0.738861      0.81
# 1679     PSAP  HsaEX0050522  0.936706  0.147605  0.789100      0.83
# 110    INTS10  HsaEX0031861  0.836123  0.045150  0.790974      0.83
#
# [1682 rows x 6 columns]

# %% [markdown]
# #### Visualize the most relevant events

# %%
# plot delta psi vs. statistics
plt.figure(figsize = (4,3), dpi = 120)
sns.scatterplot(data = diff_brain_liver, x = 'dPSI', y = 'MV[dPsi]');

# %%
# color most relevant events in a different color
dpsi = 0.4
stat = 0.1

diff_brain_liver_filtered = diff_brain_liver[(abs(diff_brain_liver['dPSI']) > dpsi) 
                                              & (diff_brain_liver['MV[dPsi]'] > stat)]

# plotting 
plt.figure(figsize = (4,3), dpi = 150)
sns.scatterplot(data = diff_brain_liver, x = 'dPSI', y = 'MV[dPsi]', color = 'steelblue', edgecolor = 'k')
sns.scatterplot(data = diff_brain_liver_filtered, x = 'dPSI', y = 'MV[dPsi]', color = 'salmon',  edgecolor = 'r');
#sns.despine(trim=True) # make it look like R's plots

# %%
diff_brain_liver_filtered.reset_index()
# Out:
#     index     GENE         EVENT     BRAIN     LIVER      dPSI  MV[dPsi]
# 0      51     GNAS  HsaEX0027841  0.974878  0.453331  0.521547      0.61
# 1     110   INTS10  HsaEX0031861  0.836123  0.045150  0.790974      0.83
# 2     178     SGCE  HsaEX0057772  0.230930  0.912760 -0.681830      0.44
# 3     253      DST  HsaEX0021043  0.427585  0.979659 -0.552075      0.36
# 4     320  RPS6KB2  HsaEX0055638  0.311156  0.989725 -0.678569      0.49
# 5     407    ACAA1  HsaEX0001661  0.489627  0.921229 -0.431602      0.29
# 6     412     EPN1  HsaEX0022820  0.135370  0.980334 -0.844964      0.56
# 7     415    SUGP2  HsaEX0062842  0.210153  0.955099 -0.744945      0.53
# 8     450    MARK3  HsaEX0037926  0.837963  0.215477  0.622485      0.71
# 9     469    APLP2  HsaEX0005151  0.885946  0.147085  0.738861      0.81
# 10    497   HNRNPM  HsaEX0030304  0.556693  0.957304 -0.400612      0.31
# 11    592    DGUOK  HsaEX0019478  0.903423  0.430370  0.473053      0.59
# 12    675     KTN1  HsaEX0035087  0.603375  0.201359  0.402015      0.52
# 13    688    RPAIN  HsaEX0055409  0.081635  0.744465 -0.662830      0.49
# 14    689    RPAIN  HsaEX0055410  0.094001  0.691341 -0.597340      0.43
# 15    779     TPM1  HsaEX0066684  0.884306  0.322388  0.561918      0.78
# 16    792      APP  HsaEX0005196  0.504927  0.972406 -0.467479      0.20
# 17    798     LGTN  HsaEX0035717  0.494931  0.921849 -0.426918      0.17
# 18    799     LGTN  HsaEX0035718  0.380487  0.944438 -0.563951      0.33
# 19    836      PTS  HsaEX0051256  0.267842  0.853491 -0.585649      0.40
# 20    921      MFF  HsaEX0038966  0.910215  0.460356  0.449859      0.57
# 21    922      MFF  HsaEX0038967  0.885648  0.484547  0.401100      0.49
# 22    966    SH2B1  HsaEX0057903  0.352451  0.976393 -0.623942      0.45
# 23    987  DHRS4L2  HsaEX0019540  0.328443  0.825491 -0.497048      0.34
# 24    995      EVL  HsaEX0023387  0.531054  0.986245 -0.455191      0.35
# 25   1145     HM13  HsaEX0030146  0.697954  0.068044  0.629910      0.69
# 26   1213   OCIAD1  HsaEX0044570  0.516658  0.978493 -0.461834      0.39
# 27   1233     BRD8  HsaEX0008424  0.949169  0.516262  0.432907      0.59
# 28   1278     RPN2  HsaEX0055524  0.566267  0.054492  0.511775      0.57
# 29   1388    RPS24  HsaEX0055568  0.998766  0.558590  0.440176      0.49
# 30   1679     PSAP  HsaEX0050522  0.936706  0.147605  0.789100      0.83

# %% [markdown]
# #### Show Isoform Switch in a Heatmap

# %%
heatmap_data = diff_brain_liver_filtered[['GENE','EVENT','BRAIN','LIVER']].set_index(['GENE','EVENT'])
heatmap_data
# Out:
#                          BRAIN     LIVER
# GENE    EVENT
# GNAS    HsaEX0027841  0.974878  0.453331
# INTS10  HsaEX0031861  0.836123  0.045150
# SGCE    HsaEX0057772  0.230930  0.912760
# DST     HsaEX0021043  0.427585  0.979659
# RPS6KB2 HsaEX0055638  0.311156  0.989725
# ACAA1   HsaEX0001661  0.489627  0.921229
# EPN1    HsaEX0022820  0.135370  0.980334
# SUGP2   HsaEX0062842  0.210153  0.955099
# MARK3   HsaEX0037926  0.837963  0.215477
# APLP2   HsaEX0005151  0.885946  0.147085
# HNRNPM  HsaEX0030304  0.556693  0.957304
# DGUOK   HsaEX0019478  0.903423  0.430370
# KTN1    HsaEX0035087  0.603375  0.201359
# RPAIN   HsaEX0055409  0.081635  0.744465
#         HsaEX0055410  0.094001  0.691341
# TPM1    HsaEX0066684  0.884306  0.322388
# APP     HsaEX0005196  0.504927  0.972406
# LGTN    HsaEX0035717  0.494931  0.921849
#         HsaEX0035718  0.380487  0.944438
# PTS     HsaEX0051256  0.267842  0.853491
# MFF     HsaEX0038966  0.910215  0.460356
#         HsaEX0038967  0.885648  0.484547
# SH2B1   HsaEX0057903  0.352451  0.976393
# DHRS4L2 HsaEX0019540  0.328443  0.825491
# EVL     HsaEX0023387  0.531054  0.986245
# HM13    HsaEX0030146  0.697954  0.068044
# OCIAD1  HsaEX0044570  0.516658  0.978493
# BRD8    HsaEX0008424  0.949169  0.516262
# RPN2    HsaEX0055524  0.566267  0.054492
# RPS24   HsaEX0055568  0.998766  0.558590
# PSAP    HsaEX0050522  0.936706  0.147605

# %%
sns.heatmap(data = heatmap_data.sort_values('LIVER'), cmap='Blues')
# Out:
# <Axes: ylabel='GENE-EVENT'>

# %% [markdown]
# #### Show distribution of PSIs for a given event/gene - BRAIN VS. LIVER
# - back to inclusion table

# %%
gene = 'OCIAD1'

gene_brain = inclusion_table[inclusion_table['GENE'] == gene].filter(like = 'FOREBRAIN')
gene_liver = inclusion_table[inclusion_table['GENE'] == gene].filter(like = 'LIVER')

# build new data frame for the event
gene_df = pd.DataFrame([gene_brain.values[0], gene_liver.values[0]], index=['brain','liver']).T

gene_brain = inclusion_table[['GENE','EVENT'] + gene_brain.columns.tolist()].loc[gene_brain.index]
gene_liver = inclusion_table[['GENE','EVENT'] + gene_liver.columns.tolist()].loc[gene_liver.index]

# melt table for plotting
gene_liver = gene_liver.melt(id_vars = ['GENE','EVENT'])
gene_brain = gene_brain.melt(id_vars = ['GENE','EVENT'])

gene_liver['tissue'] = 'LIVER'
gene_brain['tissue'] = 'BRAIN'

# combine into a table
gene_event = pd.concat([gene_liver, gene_brain])
gene_event
# Out:
#       GENE         EVENT                           variable   value tissue
# 0   OCIAD1  HsaEX0044571        LIVER.ADOLESCENT_ERR2598275   98.69  LIVER
# 1   OCIAD1  HsaEX0044572        LIVER.ADOLESCENT_ERR2598275   98.56  LIVER
# 2   OCIAD1  HsaEX0044570        LIVER.ADOLESCENT_ERR2598275   52.33  LIVER
# 3   OCIAD1  HsaEX0044571           LIVER.ELDERLY_ERR2598284   99.12  LIVER
# 4   OCIAD1  HsaEX0044572           LIVER.ELDERLY_ERR2598284   99.22  LIVER
# 5   OCIAD1  HsaEX0044570           LIVER.ELDERLY_ERR2598284   44.24  LIVER
# 6   OCIAD1  HsaEX0044571           LIVER.ELDERLY_ERR2598285  100.00  LIVER
# 7   OCIAD1  HsaEX0044572           LIVER.ELDERLY_ERR2598285  100.00  LIVER
# 8   OCIAD1  HsaEX0044570           LIVER.ELDERLY_ERR2598285   55.70  LIVER
# 9   OCIAD1  HsaEX0044571      LIVER.MIDDLE_ADULT_ERR2598310  100.00  LIVER
# 10  OCIAD1  HsaEX0044572      LIVER.MIDDLE_ADULT_ERR2598310  100.00  LIVER
# 11  OCIAD1  HsaEX0044570      LIVER.MIDDLE_ADULT_ERR2598310   94.41  LIVER
# 12  OCIAD1  HsaEX0044571       LIVER.YOUNG_ADULT_ERR2598357  100.00  LIVER
# 13  OCIAD1  HsaEX0044572       LIVER.YOUNG_ADULT_ERR2598357  100.00  LIVER
# 14  OCIAD1  HsaEX0044570       LIVER.YOUNG_ADULT_ERR2598357   99.06  LIVER
# 15  OCIAD1  HsaEX0044571       LIVER.YOUNG_ADULT_ERR2598358  100.00  LIVER
# 16  OCIAD1  HsaEX0044572       LIVER.YOUNG_ADULT_ERR2598358  100.00  LIVER
# 17  OCIAD1  HsaEX0044570       LIVER.YOUNG_ADULT_ERR2598358   99.10  LIVER
# 18  OCIAD1  HsaEX0044571       LIVER.YOUNG_ADULT_ERR2598359  100.00  LIVER
# 19  OCIAD1  HsaEX0044572       LIVER.YOUNG_ADULT_ERR2598359  100.00  LIVER
# 20  OCIAD1  HsaEX0044570       LIVER.YOUNG_ADULT_ERR2598359   97.30  LIVER
# 0   OCIAD1  HsaEX0044571    FOREBRAIN.ADOLESCENT_ERR2598266  100.00  BRAIN
# 1   OCIAD1  HsaEX0044572    FOREBRAIN.ADOLESCENT_ERR2598266  100.00  BRAIN
# 2   OCIAD1  HsaEX0044570    FOREBRAIN.ADOLESCENT_ERR2598266   51.68  BRAIN
# 3   OCIAD1  HsaEX0044571    FOREBRAIN.ADOLESCENT_ERR2598267   98.77  BRAIN
# 4   OCIAD1  HsaEX0044572    FOREBRAIN.ADOLESCENT_ERR2598267   99.03  BRAIN
# 5   OCIAD1  HsaEX0044570    FOREBRAIN.ADOLESCENT_ERR2598267   43.93  BRAIN
# 6   OCIAD1  HsaEX0044571    FOREBRAIN.ADOLESCENT_ERR2598268   98.92  BRAIN
# 7   OCIAD1  HsaEX0044572    FOREBRAIN.ADOLESCENT_ERR2598268   98.24  BRAIN
# 8   OCIAD1  HsaEX0044570    FOREBRAIN.ADOLESCENT_ERR2598268   76.88  BRAIN
# 9   OCIAD1  HsaEX0044571    FOREBRAIN.ADOLESCENT_ERR2598269  100.00  BRAIN
# 10  OCIAD1  HsaEX0044572    FOREBRAIN.ADOLESCENT_ERR2598269  100.00  BRAIN
# 11  OCIAD1  HsaEX0044570    FOREBRAIN.ADOLESCENT_ERR2598269   41.02  BRAIN
# 12  OCIAD1  HsaEX0044571       FOREBRAIN.ELDERLY_ERR2598280  100.00  BRAIN
# 13  OCIAD1  HsaEX0044572       FOREBRAIN.ELDERLY_ERR2598280  100.00  BRAIN
# 14  OCIAD1  HsaEX0044570       FOREBRAIN.ELDERLY_ERR2598280  100.00  BRAIN
# 15  OCIAD1  HsaEX0044571       FOREBRAIN.ELDERLY_ERR2598281   88.91  BRAIN
# 16  OCIAD1  HsaEX0044572       FOREBRAIN.ELDERLY_ERR2598281   89.42  BRAIN
# 17  OCIAD1  HsaEX0044570       FOREBRAIN.ELDERLY_ERR2598281   96.84  BRAIN
# 18  OCIAD1  HsaEX0044571  FOREBRAIN.MIDDLE_ADULT_ERR2598305  100.00  BRAIN
# 19  OCIAD1  HsaEX0044572  FOREBRAIN.MIDDLE_ADULT_ERR2598305  100.00  BRAIN
# 20  OCIAD1  HsaEX0044570  FOREBRAIN.MIDDLE_ADULT_ERR2598305   49.76  BRAIN
# 21  OCIAD1  HsaEX0044571  FOREBRAIN.MIDDLE_ADULT_ERR2598306   99.78  BRAIN
# 22  OCIAD1  HsaEX0044572  FOREBRAIN.MIDDLE_ADULT_ERR2598306   99.77  BRAIN
# 23  OCIAD1  HsaEX0044570  FOREBRAIN.MIDDLE_ADULT_ERR2598306   49.41  BRAIN
# 24  OCIAD1  HsaEX0044571   FOREBRAIN.YOUNG_ADULT_ERR2598346  100.00  BRAIN
# 25  OCIAD1  HsaEX0044572   FOREBRAIN.YOUNG_ADULT_ERR2598346  100.00  BRAIN
# 26  OCIAD1  HsaEX0044570   FOREBRAIN.YOUNG_ADULT_ERR2598346   98.55  BRAIN
# 27  OCIAD1  HsaEX0044571   FOREBRAIN.YOUNG_ADULT_ERR2598347  100.00  BRAIN
# 28  OCIAD1  HsaEX0044572   FOREBRAIN.YOUNG_ADULT_ERR2598347  100.00  BRAIN
# 29  OCIAD1  HsaEX0044570   FOREBRAIN.YOUNG_ADULT_ERR2598347   93.76  BRAIN
# 30  OCIAD1  HsaEX0044571   FOREBRAIN.YOUNG_ADULT_ERR2598348  100.00  BRAIN
# 31  OCIAD1  HsaEX0044572   FOREBRAIN.YOUNG_ADULT_ERR2598348  100.00  BRAIN
# 32  OCIAD1  HsaEX0044570   FOREBRAIN.YOUNG_ADULT_ERR2598348   50.66  BRAIN
# 33  OCIAD1  HsaEX0044571   FOREBRAIN.YOUNG_ADULT_ERR2598349   99.02  BRAIN
# 34  OCIAD1  HsaEX0044572   FOREBRAIN.YOUNG_ADULT_ERR2598349   99.11  BRAIN
# 35  OCIAD1  HsaEX0044570   FOREBRAIN.YOUNG_ADULT_ERR2598349   44.42  BRAIN
# 36  OCIAD1  HsaEX0044571   FOREBRAIN.YOUNG_ADULT_ERR2598350   94.38  BRAIN
# 37  OCIAD1  HsaEX0044572   FOREBRAIN.YOUNG_ADULT_ERR2598350   96.14  BRAIN
# 38  OCIAD1  HsaEX0044570   FOREBRAIN.YOUNG_ADULT_ERR2598350   97.92  BRAIN

# %%
sns.boxplot(data = gene_event, x = 'EVENT', y = 'value', hue = 'tissue', palette=['steelblue','crimson'])
sns.stripplot(data = gene_event, x = 'EVENT', y = 'value', hue = 'tissue', dodge = True, 
              palette=['w','w'], edgecolor="k", linewidth=0.5)
# Out:
# <Axes: xlabel='EVENT', ylabel='value'>

# %% [markdown]
# #### Advanced Students -> if you're bored:
# - Can the different in developmental stages (Young Adult vs. Elderly) explain such variance within the same tissue?

# %% [markdown]
# ### <span style='color:darkblue'> Step 4 - Combine with Differential Expression Data

# %%
# import diff exp data
dge_brain_liver = pd.read_table('data/degs_brain_minus_liver.tab')

# combine with splicing data
diff_brain_liver_with_dge = diff_brain_liver.merge(dge_brain_liver)
diff_brain_liver_with_dge
# Out:
#          GENE         EVENT     BRAIN     LIVER      dPSI  MV[dPsi]  \
# 0       LAS1L  HsaEX0035417  0.970019  0.987019 -0.017000      0.00
# 1       KRIT1  HsaEX0035028  0.988664  0.983987  0.004676      0.03
# 2        LAP3  HsaEX0035326  0.926628  0.985192 -0.058563      0.00
# 3        CD99  HsaEX0013932  0.736958  0.962170 -0.225211      0.07
# 4     SPATA20  HsaEX0061239  0.988164  0.982821  0.005343      0.04
# ...       ...           ...       ...       ...       ...       ...
# 1508     GNAS  HsaEX0027840  0.162524  0.114485  0.048039      0.11
# 1509    AP2M1  HsaEX0004932  0.965102  0.798988  0.166113      0.27
# 1510     PSAP  HsaEX0050522  0.936706  0.147605  0.789100      0.83
# 1511     PHB2  HsaEX0046902  0.991143  0.997811 -0.006669      0.00
# 1512  POLR2J2  HsaEX0049073  0.727191  0.833282 -0.106090      0.00
#
#           baseMean  log2FoldChange     lfcSE       stat         pvalue  \
# 0      2216.451365        1.131845  0.033133  34.160297  9.403849e-256
# 1      1180.963638       -0.436999  0.028604 -15.277385   1.081966e-52
# 2      3782.925400       -1.394485  0.064528 -21.610562  1.428978e-103
# 3      5555.285346       -0.707994  0.050586 -13.995845   1.652536e-44
# 4      2841.875975       -0.599165  0.053631 -11.171980   5.592036e-29
# ...            ...             ...       ...        ...            ...
# 1508  39418.743039        1.805893  0.038370  47.065367  8.400384e-101
# 1509  11593.784136        1.067185  0.036859  28.953033  2.570084e-184
# 1510  37128.146691       -0.065664  0.035483  -1.850601   6.422698e-02
# 1511   6692.369149       -1.764197  0.034849 -50.623662  8.400384e-101
# 1512     19.366530       -0.220182  0.092715  -2.374834   1.755683e-02
#
#                padj
# 0     7.369309e-255
# 1      3.161768e-52
# 2     5.823388e-103
# 3      4.520092e-44
# 4      1.312615e-28
# ...             ...
# 1508  9.881313e-324
# 1509  1.538306e-183
# 1510   8.377957e-02
# 1511  9.881313e-324
# 1512   2.392531e-02
#
# [1513 rows x 12 columns]

# %% [markdown]
# #### Plot Diff Expression Data vs. Diff Spliced Data

# %%
sns.scatterplot(data = diff_brain_liver_with_dge, x = 'dPSI', y = 'log2FoldChange')
# Out:
# <Axes: xlabel='dPSI', ylabel='log2FoldChange'>

# %% [markdown]
# #### What are the most relevant cases to look at?

# %%
# conditions as variables
pval = 0.05
logFC = 1
psi = 0.3
mv = 0.1

# set conditions
conditions_noDEGs = ((diff_brain_liver_with_dge['padj'] < pval) & (abs(diff_brain_liver_with_dge['log2FoldChange']) < logFC) 
                & (abs(diff_brain_liver_with_dge['dPSI']) > psi) & (diff_brain_liver_with_dge['MV[dPsi]'] > mv))

diff_brain_liver_with_dge_noDEGs = diff_brain_liver_with_dge[conditions_noDEGs]
diff_brain_liver_with_dge_noDEGs

# plot relevant events on top of all events
sns.scatterplot(data = diff_brain_liver_with_dge, x = 'dPSI', y = 'log2FoldChange', edgecolor = 'k')
sns.scatterplot(data = diff_brain_liver_with_dge_noDEGs, x = 'dPSI', y = 'log2FoldChange', color = 'salmon', edgecolor = 'k');

plt.title('no_DEGs but DiffSpliced')
plt.vlines(x = 0, ymin = -6, ymax = 6, ls = '--', color = 'lightgray', zorder=0)
plt.hlines(y = 0, xmin = -0.8, xmax = 0.8, ls = '--', color = 'lightgray', zorder=0);

# %%
diff_brain_liver_with_dge_noDEGs
# Out:
#         GENE         EVENT     BRAIN     LIVER      dPSI  MV[dPsi]  \
# 99    INTS10  HsaEX0031861  0.836123  0.045150  0.790974      0.83
# 373     EPN1  HsaEX0022820  0.135370  0.980334 -0.844964      0.56
# 376    SUGP2  HsaEX0062842  0.210153  0.955099 -0.744945      0.53
# 410    MARK3  HsaEX0037926  0.837963  0.215477  0.622485      0.71
# 428    APLP2  HsaEX0005151  0.885946  0.147085  0.738861      0.81
# 453   HNRNPM  HsaEX0030304  0.556693  0.957304 -0.400612      0.31
# 531    DGUOK  HsaEX0019478  0.903423  0.430370  0.473053      0.59
# 607     KTN1  HsaEX0035087  0.603375  0.201359  0.402015      0.52
# 619    RPAIN  HsaEX0055409  0.081635  0.744465 -0.662830      0.49
# 620    RPAIN  HsaEX0055410  0.094001  0.691341 -0.597340      0.43
# 706     TPM1  HsaEX0066684  0.884306  0.322388  0.561918      0.78
# 756      PTS  HsaEX0051256  0.267842  0.853491 -0.585649      0.40
# 876    SH2B1  HsaEX0057903  0.352451  0.976393 -0.623942      0.45
# 902      EVL  HsaEX0023387  0.531054  0.986245 -0.455191      0.35
# 1094  OCIAD1  HsaEX0044570  0.516658  0.978493 -0.461834      0.39
# 1114    BRD8  HsaEX0008424  0.949169  0.516262  0.432907      0.59
# 1173    PMS2  HsaEX0048681  0.438737  0.807906 -0.369168      0.12
# 1255   RPS24  HsaEX0055568  0.998766  0.558590  0.440176      0.49
#
#           baseMean  log2FoldChange     lfcSE       stat         pvalue  \
# 99     2600.429491       -0.829080  0.029056 -28.533782  4.464985e-179
# 373    9087.460409       -0.384722  0.043376  -8.869572   7.342783e-19
# 376    7146.915388        0.290581  0.034866   8.334210   7.801715e-17
# 410    2649.893737        0.310288  0.025446  12.194221   3.336789e-34
# 428   16372.526637       -0.494385  0.039072 -12.653230   1.073676e-36
# 453    6586.020742       -0.309383  0.030948  -9.996866   1.572965e-23
# 531     990.610123        0.109089  0.033551   3.251489   1.148024e-03
# 607    6619.048375        0.697112  0.045404  15.353521   3.354724e-53
# 619     976.343881       -0.229757  0.028897  -7.951028   1.849708e-15
# 620     976.343881       -0.229757  0.028897  -7.951028   1.849708e-15
# 706    2979.172328       -0.357059  0.051522  -6.930290   4.199785e-12
# 756    1203.333672       -0.760021  0.042331 -17.954075   4.459529e-72
# 876    3471.726805        0.263383  0.033992   7.748391   9.306389e-15
# 902    6421.764326       -0.184706  0.055787  -3.310936   9.298438e-04
# 1094   5756.239538        0.347316  0.031436  11.048356   2.232665e-28
# 1114   2389.492631       -0.148363  0.029654  -5.003064   5.642622e-07
# 1173    321.528433        0.841797  0.042146  19.973228   9.416587e-89
# 1255  16427.745950        0.121942  0.041629   2.929287   3.397408e-03
#
#                padj
# 99    2.609374e-178
# 373    1.516099e-18
# 376    1.562374e-16
# 410    8.288500e-34
# 428    2.732260e-36
# 453    3.458904e-23
# 531    1.671400e-03
# 607    9.851622e-53
# 619    3.622124e-15
# 620    3.622124e-15
# 706    7.731426e-12
# 756    1.502021e-71
# 876    1.800478e-14
# 902    1.358427e-03
# 1094   5.206354e-28
# 1114   9.242098e-07
# 1173   3.529198e-88
# 1255   4.831080e-03

# %% [markdown]
# #### What can this tell us in this context?
#
# #### Functional Diversification
# - Isoform-Specific Functions: Different functions without changing expression <br>
# - Context-Specific Roles: Tailored to specific contexts (e.g., tissue, environment) <br>
#
# #### What can this tell us in other contexts?
#
# - Stress Responses: Adapt to stress without changing expression <br>
# - Disease Mechanisms: Abnormal splicing linked to diseases <br>
# - (...)

# %% [markdown]
# ### Explore most relevant events - genes that are DEGs and DSG

# %%
# conditions as variables
pval = 0.05
logFC = 1
psi = 0.3
mv = 0.1

# set conditions
conditions = ((diff_brain_liver_with_dge['padj'] < pval) & (abs(diff_brain_liver_with_dge['log2FoldChange']) > logFC) 
                & (abs(diff_brain_liver_with_dge['dPSI']) > psi) & (diff_brain_liver_with_dge['MV[dPsi]'] > mv))

diff_brain_liver_with_dge_filtered = diff_brain_liver_with_dge[conditions]
diff_brain_liver_with_dge_filtered

# plot relevant events on top of all events
sns.scatterplot(data = diff_brain_liver_with_dge, x = 'dPSI', y = 'log2FoldChange', edgecolor = 'k')
sns.scatterplot(data = diff_brain_liver_with_dge_filtered, x = 'dPSI', y = 'log2FoldChange', color = 'crimson', edgecolor = 'k');

plt.title('Genes Diff Expressed & Diff Spliced')
plt.vlines(x = 0, ymin = -6, ymax = 6, ls = '--', color = 'lightgray', zorder=0)
plt.hlines(y = 0, xmin = -0.8, xmax = 0.8, ls = '--', color = 'lightgray', zorder=0);

# labels with results info
plt.text(-0.8, -5.5, 'down exp \n& down exon usage', fontsize = 8)
plt.text(0.4, -5.5, 'down exp \n& up exon usage', fontsize = 8)
plt.text(-0.8, 5., 'up exp \n& down exon usage', fontsize = 8)
plt.text(0.4, 5., 'up exp \n& up exon usage', fontsize = 8);

# %% [markdown]
# **Possible Interpretation of Results**
# - Increased gene expression and increased exon usage <br>
# this particular isoform might be functionally important in the liver (not so much in the brain) <br>
# splicing mechanisms produce an isoform that is necessary for particular cellular processes or responses in the liver
# - Increased gene expression and decreased exon usage <br>
# (similar as above - gene might be more important in the liver, but with a diferent isoform) <br>
# - Decreased gene expression and increased exon usage <br>
# This isoform might have a specific role even when the total gene product is less. <br>
# Compensatory Mechanism: This isoform might have higher stability, distinct functionality, or regulatory significance <br>
# - Decreased gene expression and decreased exon usage <br>
# gene and specif isoform are less needed in this context <br>

# %% [markdown]
# **Take Home Mensage: By analyzing changes in both gene expression and exon inclusion we can gain insights into**
# - Functional Isoforms: Identifying which isoforms are important in different conditions or stages.
# - Regulatory Mechanisms: Understanding how splicing and transcriptional regulation are coordinated.
# - Cellular Responses: Inferring how cells adapt their protein machinery in response to various stimuli or stresses.

# %% [markdown]
# ### <span style='color:darkblue'> More exercicies ... (if we have the time)
# - Explore PSI vs. developmental stage: compare mean PSI (adolescence vs. elderly) - might explain the variability within tissues

# %%
# import original data
inclusion_table = pd.read_table('data/betaAS_inclusion_table_reshaped.txt')

# filter for brain samples
brain_psis = inclusion_table.filter(like = 'BRAIN')

# rename columns and compare adolescent vs. elderly (extremes)
brain_psis.columns = brain_psis.columns.str.split('.').str[1].str.split('_ERR').str[0]
brain_adolescence_mean_psi = brain_psis['ADOLESCENT'].mean(axis = 1)
brain_elderly_mean_psi = brain_psis['ELDERLY'].mean(axis = 1)
brain_young_old_diff = brain_elderly_mean_psi - brain_adolescence_mean_psi

# build a new data frame
brain_old_young = pd.concat([inclusion_table[['GENE','EVENT']], 
                             brain_adolescence_mean_psi, 
                             brain_elderly_mean_psi,
                             brain_young_old_diff ], axis = 1)

brain_old_young.columns = ['GENE', 'EVENT','YOUNG_BRAIN', 'OLD_BRAIN', 'BRAIN_DIFF']

# sort by diff and keep only top events
brain_old_young = brain_old_young.sort_values('BRAIN_DIFF')
brain_old_young = brain_old_young[abs(brain_old_young['BRAIN_DIFF']) > 20]

# plotting
sns.heatmap(data = brain_old_young.set_index(['GENE','EVENT']).drop('BRAIN_DIFF', axis = 1), cmap = 'Purples');
plt.title('EXON Usage From Young to Old Peepz \n');

# %% [markdown]
# #### Links to Explore

# %% [markdown]
# https://genome.ucsc.edu/

# %% [markdown]
# https://vastdb.crg.eu/wiki/Main_Page
